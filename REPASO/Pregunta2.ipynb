# %% [markdown]
# # P2
# # Nombre: M

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize
from scipy.optimize import newton

# %%
def P(x):
    return x**5 - 6*x**4 + 2*x**3 + 20*x**2 - 27*x + 10

# %%
def P_prime(x):
    return 5*x**4 - 24*x**3 + 6*x**2 + 40*x - 27

# %%
import numpy as np
from scipy.optimize import newton
import matplotlib.pyplot as plt

#METODO DE NEWTON-RAPHSON

def newton_raphson(f, f_prime, x0, tol=1e-5, max_iter=30):
    """
    Método de Newton-Raphson para encontrar una raíz de la función f(x).
    
    Parámetros:
    f : función -> La función cuya raíz queremos encontrar.
    f_prime : función -> La derivada de f(x).
    x0 : float -> Punto inicial para la iteración.
    tol : float -> Tolerancia para la convergencia.
    max_iter : int -> Máximo número de iteraciones permitidas.
    
    Retorna:
    Una aproximación de la raíz.
    """
    x = x0
    for i in range(max_iter):
        fx = f(x)
        fpx = f_prime(x)
        
        if abs(fpx) < 1e-10:  # Evita divisiones por números muy pequeños
            raise ValueError("La derivada es muy pequeña; el método no converge.")
        
        x_new = x - fx / fpx  # Fórmula del método de Newton
        
        # Imprime información de las iteraciones (opcional)
        print(f"Iteración {i+1}: x = {x_new}, f(x) = {f(x_new)}")
        
        # Verifica si la solución es suficientemente precisa
        if abs(x_new - x) < tol:
            return x_new
        
        x = x_new  # Actualiza el valor de x
    
    raise ValueError("El método no convergió en el número máximo de iteraciones.")


if __name__ == "__main__":
    # Define la función f(x) y su derivada f'(x)
    def f(x):
        return x**5 - 6*x**4 + 2*x**3 + 20*x**2 - 27*x + 10
      # Queremos encontrar sqrt(2)
    
    def f_prime(x):
        return 5*x**4 - 24*x**3 + 6*x**2 + 40*x - 27
    
    iteraciones = [1, -6, 2, 20, -27, 10]
    for i in iteraciones:
        i+=1
        # Llamamos al método de Newton con un valor inicial
        raiz = newton_raphson(f, f_prime, x0= i)
        print(f" La raíz encontrada es: {raiz} \n")
        
# Graficar el polinomio y las raíces encontradas
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='Polinomio')
plt.scatter(raices, polinomio(np.array(raices)), color='red', zorder=5, label='Raíces')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(True, linestyle='--', alpha=0.7)
plt.title('Gráfica del Polinomio con las Raíces Encontradas')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.show()
# Out:
# Iteración 1: x = 1.657142857142857, f(x) = -3.469278124590943
# Iteración 2: x = 1.4368547445838993, f(x) = -1.0209532952721645
# Iteración 3: x = 1.291454847756548, f(x) = -0.30220755884870343
# Iteración 4: x = 1.1946246714332853, f(x) = -0.08962125406651467
# Iteración 5: x = 1.129960540226712, f(x) = -0.026588190362001995
# Iteración 6: x = 1.086754715460069, f(x) = -0.007887120208508236
# Iteración 7: x = 1.0578935832586596, f(x) = -0.002339063452161838
# Iteración 8: x = 1.038623000022467, f(x) = -0.0006935232251557011
# Iteración 9: x = 1.0257613602588698, f(x) = -0.00020558668658310353
# Iteración 10: x = 1.0171800523565355, f(x) = -6.0934794444023055e-05
# Iteración 11: x = 1.0114560023235906, f(x) = -1.8058854077906972e-05
# Iteración 12: x = 1.0076385207371659, f(x) = -5.351595518732211e-06
# Iteración 13: x = 1.0050928787058167, f(x) = -1.5858225381748525e-06
# Iteración 14: x = 1.0033954900482622, f(x) = -4.699061015855932e-07
# Iteración 15: x = 1.002263766020654, f(x) = -1.3923794028869452e-07
# Iteración 16: x = 1.0015092245734523, f(x) = -4.125697827817021e-08
# Iteración 17: x = 1.0010061707017037, f(x) = -1.222454315552568e-08
# Iteración 18: x = 1.0006707898107665, f(x) = -3.6221337040842627e-09
# Iteración 19: x = 1.0004471975733136, f(x) = -1.0732357225151645e-09
# Iteración 20: x = 1.0002981337777266, f(x) = -3.1799984867575404e-10
# Iteración 21: x = 1.000198756369655, f(x) = -9.422151947546809e-11
# Iteración 22: x = 1.000132504840931, f(x) = -2.7917224088014336e-11
# Iteración 23: x = 1.0000883376432332, f(x) = -8.270717444247566e-12
# Iteración 24: x = 1.000058897168932, f(x) = -2.4513724383723456e-12
# Iteración 25: x = 1.0000392674028211, f(x) = -7.247535904753022e-13
# Iteración 26: x = 1.0000262110568803, f(x) = -2.1316282072803006e-13
# Iteración 27: x = 1.0000175924178667, f(x) = -6.394884621840902e-14
#  La raíz encontrada es: 1.0000175924178667
#
# Iteración 1: x = -3.928571428571429, f(x) = -2061.488284271435
# Iteración 2: x = -3.121608416325343, f(x) = -637.798495053599
# Iteración 3: x = -2.5477454415679412, f(x) = -184.60921204633846
# Iteración 4: x = -2.1910819061971534, f(x) = -44.65063656910504
# Iteración 5: x = -2.0326670443488006, f(x) = -6.407728384951213
# Iteración 6: x = -2.001164346259778, f(x) = -0.22035441687096835
# Iteración 7: x = -2.0000015467582823, f(x) = -0.00029233783214266396
# Iteración 8: x = -2.0000000000027343, f(x) = -5.167777317183209e-10
#  La raíz encontrada es: -2.0000000000027343
#
# Iteración 1: x = 2.1666666666666665, f(x) = -18.74678497942387
# Iteración 2: x = 1.7599124965818973, f(x) = -5.3459542313542485
# Iteración 3: x = 1.5038405803972064, f(x) = -1.5668051720877685
# Iteración 4: x = 1.3358760321802445, f(x) = -0.4631451322697018
# Iteración 5: x = 1.2242529638322939, f(x) = -0.13729242393175412
# Iteración 6: x = 1.1497542510866687, f(x) = -0.040728892372541736
# Iteración 7: x = 1.0999796843229113, f(x) = -0.012082616757727038
# Iteración 8: x = 1.0667264577685025, f(x) = -0.0035836319713666853
# Iteración 9: x = 1.044519788414767, f(x) = -0.0010626183033402015
# Iteración 10: x = 1.029696499119086, f(x) = -0.0003150203383164296
# Iteración 11: x = 1.0198053223511023, f(x) = -9.337465429837266e-05
# Iteración 12: x = 1.0132070288522999, f(x) = -2.7673751418433312e-05
# Iteración 13: x = 1.0088062560277304, f(x) = -8.201078266267814e-06
# Iteración 14: x = 1.005871542081356, f(x) = -2.430238954076458e-06
# Iteración 15: x = 1.0039146766514506, f(x) = -7.20128554121402e-07
# Iteración 16: x = 1.002609925159019, f(x) = -2.1338289712957703e-07
# Iteración 17: x = 1.001740012830071, f(x) = -6.322683887560743e-08
# Iteración 18: x = 1.0011600364677742, f(x) = -1.8734329643166348e-08
# Iteración 19: x = 1.0007733700280088, f(x) = -5.551001436288061e-09
# Iteración 20: x = 1.0005155854786751, f(x) = -1.6447607720238011e-09
# Iteración 21: x = 1.0003437257895673, f(x) = -4.873363934621011e-10
# Iteración 22: x = 1.0002291519338071, f(x) = -1.4439649476116756e-10
# Iteración 23: x = 1.000152769051692, f(x) = -4.278533083379443e-11
# Iteración 24: x = 1.0001018460194049, f(x) = -1.2676082405960187e-11
# Iteración 25: x = 1.000067899948067, f(x) = -3.7552183584921295e-12
# Iteración 26: x = 1.0000452748473136, f(x) = -1.1155520951433573e-12
# Iteración 27: x = 1.0000301576529493, f(x) = -3.304023721284466e-13
# Iteración 28: x = 1.0000200664228034, f(x) = -9.947598300641403e-14
# Iteración 29: x = 1.0000132040443717, f(x) = -2.842170943040401e-14
#  La raíz encontrada es: 1.0000132040443717
#
# Iteración 1: x = 17.093418259023355, f(x) = 962448.8441855471
# Iteración 2: x = 13.9827592230627, f(x) = 314168.4172999821
# Iteración 3: x = 11.513425109631093, f(x) = 102283.96136763996
# Iteración 4: x = 9.563647412966619, f(x) = 33142.34688718142
# Iteración 5: x = 8.039068687367072, f(x) = 10640.9291313671
# Iteración 6: x = 6.869275212771935, f(x) = 3352.0832896683783
# Iteración 7: x = 6.006352142569197, f(x) = 1010.9946235839095
# Iteración 8: x = 5.424221511649878, f(x) = 272.7433670090443
# Iteración 9: x = 5.108767950488776, f(x) = 53.632757489028904
# Iteración 10: x = 5.009410810781487, f(x) = 4.2515787388305455
# Iteración 11: x = 5.000078245514938, f(x) = 0.03505643969950256
# Iteración 12: x = 5.000000005465913, f(x) = 2.4487291909736086e-06
# Iteración 13: x = 5.0, f(x) = 0.0
#  La raíz encontrada es: 5.0
#
# Iteración 1: x = -20.595641646489106, f(x) = -4793751.601142183
# Iteración 2: x = -16.280872544976056, f(x) = -1568343.4519278929
# Iteración 3: x = -12.8399132559545, f(x) = -512647.27069879946
# Iteración 4: x = -10.100713374970521, f(x) = -167329.84073235226
# Iteración 5: x = -7.926426244365561, f(x) = -54488.420544400135
# Iteración 6: x = -6.208736766320528, f(x) = -17672.009457834018
# Iteración 7: x = -4.862803313370977, f(x) = -5689.942235546647
# Iteración 8: x = -3.8237339103853456, f(x) = -1806.1919626188658
# Iteración 9: x = -3.044663581300941, f(x) = -556.0726762317529
# Iteración 10: x = -2.4961984690185686, f(x) = -158.9588569777523
# Iteración 11: x = -2.1636188088394954, f(x) = -37.112323180677734
# Iteración 12: x = -2.0247230166751216, f(x) = -4.806041314990196
# Iteración 13: x = -2.0006743339349065, f(x) = -0.12754736216925266
# Iteración 14: x = -2.000000519178672, f(x) = -9.812482727511451e-05
# Iteración 15: x = -2.0000000000003078, f(x) = -5.81721337766794e-11
#  La raíz encontrada es: -2.0000000000003078
#
# Iteración 1: x = 9.160377358490566, f(x) = 25231.457024751377
# Iteración 2: x = 7.726882026185806, f(x) = 8073.864035307566
# Iteración 3: x = 6.634581443042911, f(x) = 2524.834037153666
# Iteración 4: x = 5.8409414814612335, f(x) = 748.0377008249237
# Iteración 5: x = 5.324517455421913, f(x) = 192.23392951233834
# Iteración 6: x = 5.068877077847436, f(x) = 32.798112630051435
# Iteración 7: x = 5.0039309957102125, f(x) = 1.767275191910585
# Iteración 8: x = 5.0000137362927095, f(x) = 0.006153934608306599
# Iteración 9: x = 5.000000000168467, f(x) = 7.547328095824923e-08
# Iteración 10: x = 5.0, f(x) = 0.0
#  La raíz encontrada es: 5.0

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import newton

def polinomio(x):
    return x**5 - 6*x**4 + 2*x**3 + 20*x**2 - 27*x + 10
def derivada_polinomio(x):
    return 5*x**4 - 24*x**3 + 6*x**2 + 40*x - 27
estimaciones_iniciales = [-2, 0, 1, 2, 5, 10]
raices = [newton(polinomio, est, fprime=derivada_polinomio) for est in estimaciones_iniciales]

x = np.linspace(-3, 6, 400)
y = polinomio(x)

plt.figure(figsize=(12, 8))
plt.plot(x, y, label='Polinomio', color='blue')

plt.scatter(raices_unicas, polinomio(np.array(raices_unicas)), color='red', zorder=5, label='Raíces')

plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(True, linestyle='--', alpha=0.7)
plt.title('Gráfica del Polinomio con las Raíces Encontradas')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.show()

print (raices)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 18
#      15 plt.figure(figsize=(12, 8))
#      16 plt.plot(x, y, label='Polinomio', color='blue')
# ---> 18 plt.scatter(raices_unicas, polinomio(np.array(raices_unicas)), color='red', zorder=5, label='Raíces')
#      20 plt.axhline(0, color='black',linewidth=0.5)
#      21 plt.axvline(0, color='black',linewidth=0.5)
#
# NameError: name 'raices_unicas' is not defined

# %%
import numpy as np
from scipy import optimize

def polinomio(x):
    return x**5 - 6*x**4 + 2*x**3 + 20*x**2 - 27*x + 10

# Encontrar intervalos donde pueden haber raíces
x = np.linspace(-10, 10, 1000)
y = polinomio(x)
cambios_signo = np.where(np.diff(np.sign(y)))[0]

raices = []

for i in cambios_signo:
    a, b = x[i], x[i+1]
    try:
        raiz = optimize.brentq(polinomio, a, b)
        raices.append(raiz)
    except:
        pass

# Intentar encontrar raíces complejas
coeficientes = [1, -6, 2, 20, -27, 10]
raices_complejas = np.roots(coeficientes)

# Filtrar raíces reales únicas
raices_reales = [r.real for r in raices_complejas if abs(r.imag) < 1e-10 and r.real not in raices]
raices.extend(raices_reales)

# Ordenar raíces
raices.sort()

# Imprimir raíces
for i, raiz in enumerate(raices, 1):
    print(f"x{i} = {raiz:.10f}")

# Rellenar con NaN si hay menos raíces
for i in range(len(raices)+1, 7):
    print(f"x{i} = NaN")

# Graficar el polinomio y las raíces encontradas
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='Polinomio')
plt.scatter(raices, polinomio(np.array(raices)), color='red', zorder=5, label='Raíces')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(True, linestyle='--', alpha=0.7)
plt.title('Gráfica del Polinomio con las Raíces Encontradas')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.show()
# Out:
# x1 = -2.0000000000
# x2 = -2.0000000000
# x3 = 0.9999938349
# x4 = 1.0000081704
# x5 = 5.0000000000
# x6 = 5.0000000000
